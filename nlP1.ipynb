# %% [markdown]
# <a href="https://colab.research.google.com/github/div-nimje29/divya-29/blob/main/nlP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# %% [markdown]
# #parameters

# %%
vocab_size=100 # vocablary size
embedding_dim=16
hidden_units=32
imput_length=5
output_length=5#length of output

# %%
# create example data
#input sequences:[[1,2,3,4,5]....]
  #
num_sequences =1000
x= np.random.randint(1,vocab_size,size=(num_sequences,imput_length))
y=np.flip(x,axis=1)
